# %% [markdown]
# ## Connecting to GBQ

# %% [markdown]
# ### Imports for the code

# %%
# Do our imports for the code
from google.cloud import bigquery
from google.oauth2 import service_account
import os

# %%
path_to_files = 'C:\\Users\\meand\\Documents\\Grad School\\Fall2020\\Applied Data Analytics\\Wedge\\ada-wedge\\bigwedge_clean\\'

# %%
clean_wedge = os.listdir("bigwedge_clean")

# %%
# values are specific to my machine and project 
service_path = "C:\\Users\meand\\Documents\\Grad School\Fall2020\\Applied Data Analytics\\Wedge\\ada-wedge\\"
service_file = 'Wedge Project-ed75ab1189b3.json' # this is your authentication information  
gbq_proj_id = 'wedge-project-290522'  # change this to your project_id
gbq_dataset_id = 'big_wedge_1' # and change this to your data set ID

private_key =service_path + service_file

# %%
# pass in our credentials so that Python has permission to access our project.
credentials = service_account.Credentials.from_service_account_file(service_path + service_file)

# %%
# establish our connection
client = bigquery.Client(credentials = credentials, project=gbq_proj_id)

# %% [markdown]
# ### Creating Tables

# %%
def tbl_exists(client, table_ref):
    from google.cloud.exceptions import NotFound
    try:
        client.get_table(table_ref)
        return True
    except NotFound:
        return False

# %%
job_config = bigquery.LoadJobConfig()
job_config.write_disposition = bigquery.WriteDisposition.WRITE_APPEND
job_config.schema_update_options = [
    bigquery.SchemaUpdateOption.ALLOW_FIELD_ADDITION # This allows us to modify the table. 
]

# %%
job_config.schema = [
    bigquery.SchemaField("datetime", "TIMESTAMP", mode="NULLABLE"),
    bigquery.SchemaField("register_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("emp_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("trans_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("upc", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("description", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_type", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_subtype", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("trans_status", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("department", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("quantity", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("Scale", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("cost", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("unitPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("total", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("regPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("altPrice", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("tax", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("taxexempt", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("foodstamp", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("wicable", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("memDiscount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discountable", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("discounttype", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("voided", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("percentDiscount", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("ItemQtty", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("volDiscType", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("volume", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("VolSpecial", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("mixMatch", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("matched", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("memType", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("staff", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("numflag", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("itemstatus", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("tenderstatus", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("charflag", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("varflag", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("batchHeaderID", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("local", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("organic", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("display", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("receipt", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("card_no", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("store", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("branch", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("match_id", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("trans_id", "FLOAT", mode="NULLABLE"),
]
job_config.source_format = bigquery.SourceFormat.CSV
job_config.skip_leading_rows = 1

# %%
for file in clean_wedge:
    my_table,junk = file.split("_clean")#splits on _clean in csv files and removes rest as junk
    table_full_name = ".".join([gbq_proj_id,gbq_dataset_id,my_table]) #creates GBQ table name
    
    if not tbl_exists(client, table_full_name) :
        table_ref = client.create_table(table = table_full_name)
    else :
        table_ref = client.get_table(table_full_name)
    
    table = client.get_table(table_ref)
    print("Table {} contains {} columns".format(table_ref.table_id,len(table.schema)))
    
    with open(path_to_files + file, "rb") as source_file:
        job = client.load_table_from_file(
            source_file,
            table_ref,
            location="US",  # Must match the destination dataset location.
            job_config=job_config,
        )  # API request
    job.result()  # Waits for table load to complete.
    print("Loaded {} rows into {}:{}.".format(job.output_rows, 'wedge_example', table_ref.table_id))
    

    # Checks the updated length of the schema
    table = client.get_table(table)
    print("Table {} now contains {} columns.".format(table_ref.table_id, len(table.schema)))
# Out:
# Table transArchive_201001_201003 contains 0 columns
# Loaded 2998330 rows into wedge_example:transArchive_201001_201003.
# Table transArchive_201001_201003 now contains 50 columns.
# Table transArchive_201004_201006 contains 0 columns
# Loaded 3185807 rows into wedge_example:transArchive_201004_201006.
# Table transArchive_201004_201006 now contains 50 columns.
# Table transArchive_201007_201009 contains 0 columns
# Loaded 2992585 rows into wedge_example:transArchive_201007_201009.
# Table transArchive_201007_201009 now contains 50 columns.
# Table transArchive_201010_201012 contains 0 columns
# Loaded 2957586 rows into wedge_example:transArchive_201010_201012.
# Table transArchive_201010_201012 now contains 50 columns.
# Table transArchive_201101_201103 contains 0 columns
# Loaded 2920826 rows into wedge_example:transArchive_201101_201103.
# Table transArchive_201101_201103 now contains 50 columns.
# Table transArchive_201104 contains 0 columns
# Loaded 1066334 rows into wedge_example:transArchive_201104.
# Table transArchive_201104 now contains 50 columns.
# Table transArchive_201105 contains 0 columns
# Loaded 1068515 rows into wedge_example:transArchive_201105.
# Table transArchive_201105 now contains 50 columns.
# Table transArchive_201106 contains 0 columns
# Loaded 992906 rows into wedge_example:transArchive_201106.
# Table transArchive_201106 now contains 50 columns.
# Table transArchive_201107_201109 contains 0 columns
# Loaded 3011935 rows into wedge_example:transArchive_201107_201109.
# Table transArchive_201107_201109 now contains 50 columns.
# Table transArchive_201110_201112 contains 0 columns
# Loaded 3121117 rows into wedge_example:transArchive_201110_201112.
# Table transArchive_201110_201112 now contains 50 columns.
# Table transArchive_201201_201203 contains 0 columns
# Loaded 2989644 rows into wedge_example:transArchive_201201_201203.
# Table transArchive_201201_201203 now contains 50 columns.
# Table transArchive_201201_201203_inactive contains 0 columns
# Loaded 245772 rows into wedge_example:transArchive_201201_201203_inactive.
# Table transArchive_201201_201203_inactive now contains 50 columns.
# Table transArchive_201204_201206 contains 0 columns
# Loaded 3083546 rows into wedge_example:transArchive_201204_201206.
# Table transArchive_201204_201206 now contains 50 columns.
# Table transArchive_201204_201206_inactive contains 0 columns
# Loaded 237990 rows into wedge_example:transArchive_201204_201206_inactive.
# Table transArchive_201204_201206_inactive now contains 50 columns.
# Table transArchive_201207_201209 contains 0 columns
# Loaded 2925608 rows into wedge_example:transArchive_201207_201209.
# Table transArchive_201207_201209 now contains 50 columns.
# Table transArchive_201207_201209_inactive contains 0 columns
# Loaded 190877 rows into wedge_example:transArchive_201207_201209_inactive.
# Table transArchive_201207_201209_inactive now contains 50 columns.
# Table transArchive_201210_201212 contains 0 columns
# Loaded 2893637 rows into wedge_example:transArchive_201210_201212.
# Table transArchive_201210_201212 now contains 50 columns.
# Table transArchive_201210_201212_inactive contains 0 columns
# Loaded 162988 rows into wedge_example:transArchive_201210_201212_inactive.
# Table transArchive_201210_201212_inactive now contains 50 columns.
# Table transArchive_201301_201303 contains 0 columns
# Loaded 2903987 rows into wedge_example:transArchive_201301_201303.
# Table transArchive_201301_201303 now contains 50 columns.
# Table transArchive_201301_201303_inactive contains 0 columns
# Loaded 148623 rows into wedge_example:transArchive_201301_201303_inactive.
# Table transArchive_201301_201303_inactive now contains 50 columns.
# Table transArchive_201304_201306 contains 0 columns
# Loaded 3025434 rows into wedge_example:transArchive_201304_201306.
# Table transArchive_201304_201306 now contains 50 columns.
# Table transArchive_201304_201306_inactive contains 0 columns
# Loaded 137628 rows into wedge_example:transArchive_201304_201306_inactive.
# Table transArchive_201304_201306_inactive now contains 50 columns.
# Table transArchive_201307_201309 contains 0 columns
# Loaded 2997135 rows into wedge_example:transArchive_201307_201309.
# Table transArchive_201307_201309 now contains 50 columns.
# Table transArchive_201307_201309_inactive contains 0 columns
# Loaded 104468 rows into wedge_example:transArchive_201307_201309_inactive.
# Table transArchive_201307_201309_inactive now contains 50 columns.
# Table transArchive_201310_201312 contains 0 columns
# Loaded 2922057 rows into wedge_example:transArchive_201310_201312.
# Table transArchive_201310_201312 now contains 50 columns.
# Table transArchive_201310_201312_inactive contains 0 columns
# Loaded 79156 rows into wedge_example:transArchive_201310_201312_inactive.
# Table transArchive_201310_201312_inactive now contains 50 columns.
# Table transArchive_201401_201403 contains 0 columns
# Loaded 2916194 rows into wedge_example:transArchive_201401_201403.
# Table transArchive_201401_201403 now contains 50 columns.
# Table transArchive_201401_201403_inactive contains 0 columns
# Loaded 52614 rows into wedge_example:transArchive_201401_201403_inactive.
# Table transArchive_201401_201403_inactive now contains 50 columns.
# Table transArchive_201404_201406 contains 0 columns
# Loaded 3154267 rows into wedge_example:transArchive_201404_201406.
# Table transArchive_201404_201406 now contains 50 columns.
# Table transArchive_201404_201406_inactive contains 0 columns
# Loaded 49069 rows into wedge_example:transArchive_201404_201406_inactive.
# Table transArchive_201404_201406_inactive now contains 50 columns.
# Table transArchive_201407_201409 contains 0 columns
# Loaded 3030409 rows into wedge_example:transArchive_201407_201409.
# Table transArchive_201407_201409 now contains 50 columns.
# Table transArchive_201407_201409_inactive contains 0 columns
# Loaded 28323 rows into wedge_example:transArchive_201407_201409_inactive.
# Table transArchive_201407_201409_inactive now contains 50 columns.
# Table transArchive_201410_201412 contains 0 columns
# Loaded 2931416 rows into wedge_example:transArchive_201410_201412.
# Table transArchive_201410_201412 now contains 50 columns.
# Table transArchive_201410_201412_inactive contains 0 columns
# Loaded 7964 rows into wedge_example:transArchive_201410_201412_inactive.
# Table transArchive_201410_201412_inactive now contains 50 columns.
# Table transArchive_201501_201503 contains 0 columns
# Loaded 3041129 rows into wedge_example:transArchive_201501_201503.
# Table transArchive_201501_201503 now contains 50 columns.
# Table transArchive_201504_201506 contains 0 columns
# Loaded 3274964 rows into wedge_example:transArchive_201504_201506.
# Table transArchive_201504_201506 now contains 50 columns.
# Table transArchive_201507_201509 contains 0 columns
# Loaded 3124699 rows into wedge_example:transArchive_201507_201509.
# Table transArchive_201507_201509 now contains 50 columns.
# Table transArchive_201510 contains 0 columns
# Loaded 1006055 rows into wedge_example:transArchive_201510.
# Table transArchive_201510 now contains 50 columns.
# Table transArchive_201511 contains 0 columns
# Loaded 993744 rows into wedge_example:transArchive_201511.
# Table transArchive_201511 now contains 50 columns.
# Table transArchive_201512 contains 0 columns
# Loaded 960017 rows into wedge_example:transArchive_201512.
# Table transArchive_201512 now contains 50 columns.
# Table transArchive_201601 contains 0 columns
# Loaded 979408 rows into wedge_example:transArchive_201601.
# Table transArchive_201601 now contains 50 columns.
# Table transArchive_201602 contains 0 columns
# Loaded 874853 rows into wedge_example:transArchive_201602.
# Table transArchive_201602 now contains 50 columns.
# Table transArchive_201603 contains 0 columns
# Loaded 964635 rows into wedge_example:transArchive_201603.
# Table transArchive_201603 now contains 50 columns.
# Table transArchive_201604 contains 0 columns
# Loaded 930359 rows into wedge_example:transArchive_201604.
# Table transArchive_201604 now contains 50 columns.
# Table transArchive_201605 contains 0 columns
# Loaded 938769 rows into wedge_example:transArchive_201605.
# Table transArchive_201605 now contains 50 columns.
# Table transArchive_201606 contains 0 columns
# Loaded 862329 rows into wedge_example:transArchive_201606.
# Table transArchive_201606 now contains 50 columns.
# Table transArchive_201607 contains 0 columns
# Loaded 872161 rows into wedge_example:transArchive_201607.
# Table transArchive_201607 now contains 50 columns.
# Table transArchive_201608 contains 0 columns
# Loaded 858168 rows into wedge_example:transArchive_201608.
# Table transArchive_201608 now contains 50 columns.
# Table transArchive_201609 contains 0 columns
# Loaded 861248 rows into wedge_example:transArchive_201609.
# Table transArchive_201609 now contains 50 columns.
# Table transArchive_201610 contains 0 columns
# Loaded 905092 rows into wedge_example:transArchive_201610.
# Table transArchive_201610 now contains 50 columns.
# Table transArchive_201611 contains 0 columns
# Loaded 925314 rows into wedge_example:transArchive_201611.
# Table transArchive_201611 now contains 50 columns.
# Table transArchive_201612 contains 0 columns
# Loaded 915707 rows into wedge_example:transArchive_201612.
# Table transArchive_201612 now contains 50 columns.
# Table transArchive_201701 contains 0 columns
# Loaded 936741 rows into wedge_example:transArchive_201701.
# Table transArchive_201701 now contains 50 columns.
